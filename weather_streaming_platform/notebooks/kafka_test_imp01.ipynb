# %%
import requests
import json
from datetime import datetime

# %%
CITY= {
    "name":"shimla",
    "latitude":31.10,
    "longitude":77.17
}

print(CITY)
# Out:
# {'name': 'shimla', 'latitude': 31.1, 'longitude': 77.17}

# %%
# build weather api url 
BASE_URL= "https://api.open-meteo.com/v1/forecast"
latitude=CITY["latitude"]
longitude=CITY["longitude"]

url=(
    f"{BASE_URL}"
    f"?latitude={latitude}"
    f"&longitude={longitude}"
    f"&current=temperature_2m,relative_humidity_2m,"
    f"wind_speed_10m,pressure_msl"
)

print(url)
# Out:
# https://api.open-meteo.com/v1/forecast?latitude=31.1&longitude=77.17&current=temperature_2m,relative_humidity_2m,wind_speed_10m,pressure_msl

# %%
## send request
response= requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
print(response.status_code)
# Out:
# 200

# %%
# json response 
weather_data=response.json()
print(json.dumps(weather_data,indent=4))
# Out:
# {
#     "latitude": 31.107204,
#     "longitude": 77.17339,
#     "generationtime_ms": 0.0692605972290039,
#     "utc_offset_seconds": 0,
#     "timezone": "GMT",
#     "timezone_abbreviation": "GMT",
#     "elevation": 1940.0,
#     "current_units": {
#         "time": "iso8601",
#         "interval": "seconds",
#         "temperature_2m": "\u00b0C",
#         "relative_humidity_2m": "%",
#         "wind_speed_10m": "km/h",
#         "pressure_msl": "hPa"
#     },
#     "current": {
#         "time": "2026-06-25T16:15",
#         "interval": 900,
#         "temperature_2m": 16.3,
#         "relative_humidity_2m": 93,
#         "wind_speed_10m": 1.3,
#         "pressure_msl": 1008.8
#     }
# }

# %%
## event modeling and event creation 

print(weather_data.keys())
# Out:
# dict_keys(['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation', 'elevation', 'current_units', 'current'])

# %%
current=weather_data["current"]
print(json.dumps(current,indent=4))
# Out:
# {
#     "time": "2026-06-25T16:15",
#     "interval": 900,
#     "temperature_2m": 16.3,
#     "relative_humidity_2m": 93,
#     "wind_speed_10m": 1.3,
#     "pressure_msl": 1008.8
# }

# %%
## create weather event
